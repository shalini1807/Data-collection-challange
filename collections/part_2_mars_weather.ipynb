# %% [markdown]
# # Module 11 Challenge
# ## Deliverable 2: Scrape and Analyze Mars Weather Data

# %%
# Import relevant libraries
from splinter import Browser
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
import pandas as pd

# %%
browser = Browser('chrome')

# %% [markdown]
# ### Step 1: Visit the Website
#
# Use automated browsing to visit the [Mars Temperature Data Site](https://static.bc-edx.com/data/web/mars_facts/temperature.html). Inspect the page to identify which elements to scrape.
#
#    > **Hint** To identify which elements to scrape, you might want to inspect the page by using Chrome DevTools to discover whether the table contains usable classes.

# %%
# Visit the website
# https://static.bc-edx.com/data/web/mars_facts/temperature.html
url = "https://static.bc-edx.com/data/web/mars_facts/temperature.html"
browser.visit(url)

# %% [markdown]
# ### Step 2: Scrape the Table
#
# Create a Beautiful Soup object and use it to scrape the data in the HTML table.
#
# Note that this can also be achieved by using the Pandas `read_html` function. However, use Beautiful Soup here to continue sharpening your web scraping skills.

# %%
# Create a Beautiful Soup Object
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
# Extract all rows of data
table = soup.find('table')
rows = table.find_all('tr')

# %% [markdown]
# ### Step 3: Store the Data
#
# Assemble the scraped data into a Pandas DataFrame. The columns should have the same headings as the table on the website. Here’s an explanation of the column headings:
#
# * `id`: the identification number of a single transmission from the Curiosity rover
# * `terrestrial_date`: the date on Earth
# * `sol`: the number of elapsed sols (Martian days) since Curiosity landed on Mars
# * `ls`: the solar longitude
# * `month`: the Martian month
# * `min_temp`: the minimum temperature, in Celsius, of a single Martian day (sol)
# * `pressure`: The atmospheric pressure at Curiosity's location

# %%
# Create an empty list
table_data = []


# Loop through the scraped data to create a list of rows
for row in rows:
    # Extract all columns (inside <td> or <th> tags)
    cols = row.find_all(['td', 'th'])
    
    # Get the text content from each column
    data = [col.text.strip() for col in cols]
    
    # Add the row data to the list
    table_data.append(data)

# Optionally, print or do further processing with the scraped data
for row in table_data:
    print(row)
# Out:
# ['id', 'terrestrial_date', 'sol', 'ls', 'month', 'min_temp', 'pressure']
# ['2', '2012-08-16', '10', '155', '6', '-75.0', '739.0']
# ['13', '2012-08-17', '11', '156', '6', '-76.0', '740.0']
# ['24', '2012-08-18', '12', '156', '6', '-76.0', '741.0']
# ['35', '2012-08-19', '13', '157', '6', '-74.0', '732.0']
# ['46', '2012-08-20', '14', '157', '6', '-74.0', '740.0']
# ['57', '2012-08-21', '15', '158', '6', '-78.0', '740.0']
# ['68', '2012-08-22', '16', '158', '6', '-77.0', '740.0']
# ['79', '2012-08-23', '17', '159', '6', '-76.0', '742.0']
# ['112', '2012-08-27', '21', '161', '6', '-74.0', '741.0']
# ['114', '2012-08-28', '22', '162', '6', '-74.0', '742.0']
# ['123', '2012-08-29', '23', '162', '6', '-75.0', '741.0']
# ['134', '2012-08-30', '24', '163', '6', '-75.0', '742.0']
# ['145', '2012-08-31', '25', '163', '6', '-75.0', '743.0']
# ['156', '2012-09-01', '26', '164', '6', '-76.0', '745.0']
# ['163', '2012-09-02', '27', '164', '6', '-75.0', '743.0']
# ...

# %%
# Assume the first row contains column names (headers)
column_names = table_data[0]  # First row as header
table_data = table_data[1:]    # Remaining rows as data

# Create a Pandas DataFrame by using the list of rows and a list of the column names
df = pd.DataFrame(table_data, columns=column_names)

# %%
# Confirm DataFrame was created successfully
df.head(5)
# Out:
#    id terrestrial_date sol   ls month min_temp pressure
# 0   2       2012-08-16  10  155     6    -75.0    739.0
# 1  13       2012-08-17  11  156     6    -76.0    740.0
# 2  24       2012-08-18  12  156     6    -76.0    741.0
# 3  35       2012-08-19  13  157     6    -74.0    732.0
# 4  46       2012-08-20  14  157     6    -74.0    740.0

# %% [markdown]
# ### Step 4: Prepare Data for Analysis
#
# Examine the data types that are currently associated with each column. If necessary, cast (or convert) the data to the appropriate `datetime`, `int`, or `float` data types.
#
#   > **Hint** You can use the Pandas `astype` and `to_datetime` methods to accomplish this task.

# %%
# Examine data type of each column
df.dtypes
# Out:
# id                  object
# terrestrial_date    object
# sol                 object
# ls                  object
# month               object
# min_temp            object
# pressure            object
# dtype: object

# %%
# Change data types for data analysis
df['terrestrial_date'] = pd.to_datetime(df['terrestrial_date'], errors='coerce')  # Convert to numeric
df['sol'] = pd.to_numeric(df['sol'], errors='coerce')       # Convert to datetime
df['ls'] = pd.to_numeric(df['ls'], errors='coerce')  
df['min_temp'] = pd.to_numeric(df['min_temp'],errors = 'coerce')
df['pressure'] = pd.to_numeric(df['pressure'],errors = 'coerce')

# %%
# Confirm type changes were successful by examining data types again
df.dtypes
# Out:
# id                          object
# terrestrial_date    datetime64[ns]
# sol                          int64
# ls                           int64
# month                       object
# min_temp                   float64
# pressure                   float64
# dtype: object

# %% [markdown]
# ### Step 5: Analyze the Data
#
# Analyze your dataset by using Pandas functions to answer the following questions:
#
# 1. How many months exist on Mars?
# 2. How many Martian (and not Earth) days worth of data exist in the scraped dataset?
# 3. What are the coldest and the warmest months on Mars (at the location of Curiosity)? To answer this question:
#     * Find the average the minimum daily temperature for all of the months.
#     * Plot the results as a bar chart.
# 4. Which months have the lowest and the highest atmospheric pressure on Mars? To answer this question:
#     * Find the average the daily atmospheric pressure of all the months.
#     * Plot the results as a bar chart.
# 5. About how many terrestrial (Earth) days exist in a Martian year? To answer this question:
#     * Consider how many days elapse on Earth in the time that Mars circles the Sun once.
#     * Visually estimate the result by plotting the daily minimum temperature.

# %%
# 1. How many months are there on Mars?
df['month'].nunique()
# Out:
# 12

# %%
# 2. How many sols (Martian days) worth of data are there?
df['sol'].nunique()
# Out:
# 1867

# %%
min_temp_by_month = min_temp_by_month.sort_index()

# %%
# 3. What is the average minimum temperature by month?
df['month'] = df['month'].astype(int)

avg_temp= df.groupby('month')['min_temp'].mean()
month = avg_temp.sort_index()
month
# Out:
# month
# 1    -77.160920
# 2    -79.932584
# 3    -83.307292
# 4    -82.747423
# 5    -79.308725
# 6    -75.299320
# 7    -72.281690
# 8    -68.382979
# 9    -69.171642
# 10   -71.982143
# 11   -71.985507
# 12   -74.451807
# Name: min_temp, dtype: float64

# %%
# Plot the average minimum temperature by month
plt.figure(figsize=(10, 5))
plt.bar(avg_temp.index, avg_temp.values, color='skyblue')
plt.title('Average Minimum Temperature by Month')
plt.xlabel('Month')
plt.ylabel('Average Minimum Temperature')
plt.xticks(range(0,13))  # Set x-ticks to be the month numbers
#plt.grid(axis='y')

# Show the plot
plt.show()

# %%
# Identify the coldest and hottest months in Curiosity's location by sorting the previous graph
# Sort by temperature (values)
avg_temp = avg_temp.sort_values()

#plot
plt.figure(figsize=(10, 5))
plt.bar(avg_temp.index, avg_temp.values, color='skyblue')
plt.title('Average Minimum Temperature by Month')
plt.xlabel('Month')
plt.ylabel('Temperature in Celsius')
plt.xticks(range(0, 12))  # Set x-ticks to be the month numbers
#plt.grid(axis='y')  # Optional grid
plt.show()

# %%
# 4. What is the average pressure by month?
avg_pressure = df.groupby('month')['pressure'].mean()
avg_pressure
# Out:
# month
# 1     862.488506
# 2     889.455056
# 3     877.322917
# 4     806.329897
# 5     748.557047
# 6     745.054422
# 7     795.105634
# 8     873.829787
# 9     913.305970
# 10    887.312500
# 11    857.014493
# 12    842.156627
# Name: pressure, dtype: float64

# %%
# Plot the average pressure by month
plt.figure(figsize=(8, 5))
plt.bar(avg_pressure.index, avg_pressure.values, color='skyblue')
plt.title('Average pressure by Month')
plt.xlabel('Month')
plt.ylabel('Atmospheric Pressure')
plt.xticks(avg_pressure.index)  # Set x-ticks to be the month numbers
#plt.grid(axis='y')

# Show the plot
plt.show()

# %%
# Identify the lowest and highest pressure months in Curiosity's location by sorting the previous graph
#sort values
avg_pressure = avg_pressure.sort_values()


#plot
plt.figure(figsize=(10, 5))
plt.bar(avg_pressure.index, avg_pressure.values, color='skyblue')
plt.title('Average Pressure by Month')
plt.xlabel('Month')
plt.ylabel('Atmospheric Pressure')
plt.xticks(range(0, 12))  # Set x-ticks to be the month numbers
plt.show()

# %%
# 5. How many terrestrial (Earth) days are there in a Martian year?
# Visually estimate the result by plotting the daily minimum temperature of each observation in the data set.
df['terrestrial_date'] = pd.to_datetime(df['terrestrial_date'])
df = df.sort_values('terrestrial_date')

# Calculate the number of days since the first date
df['days'] = (df['terrestrial_date'] - df['terrestrial_date'].min()).dt.days

plt.figure(figsize=(8, 5))
plt.plot(df['days'], df['min_temp'], color='b', linewidth=1)
plt.title('Minimum Temperature over Time')
plt.xlabel('Number of terrestrial days')
plt.ylabel('Minimum temperature')

# Adjust x-axis ticks
max_days = df['days'].max()
plt.xticks(range(0, max_days + 1, 250))  # Set ticks every 250 days
#plt.grid()
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Minimum Temperature
#
# ##### Analysis:
#
# The graph depicts average minimum temperatures by month. Temperatures range from around -80°C to 0°C, with a clear seasonal pattern indicating the Southern Hemisphere. The coldest months are March and April, while December and January are the warmest, with minimum temperatures approaching. There's a prolonged winter from February to October, with a short 2-3 month summer. The significant 80°C temperature swing between seasons and extremely low winter temperatures suggest a challenging environment for life and human activities. The coldest month is 3 with an average minimum temperature of -83.307291666
# 66667°C
# The hottest month is 8 with an average minimum temperature of -68.38297873
# 40425°C. This climate would require specialized equipment and careful planning for any operations. The data reveals a stark, polar climate cycle with brief, relatively mild summers and long, intensely cold winters typical of Earth's southernmost regions.

# %% [markdown]
# #### Atmospheric Pressure
#
# ###### Analysis:
#
# The graph depicts the average Atmospheric Pressure by month over a year. Where the  x-axis represents the months while the y-axis shows the atmospheric pressure. The pressure values range from approximately 750 to 900 units.
#
# There's a clear seasonal pattern visible in the data. Pressure tends to be higher in the winter monthsDecember and lower in the summer months around June The highest pressure is observed in month 9 (September), while the lowest occurs in month 6 (June). There's a gradual decrease in pressure from winter to summer, followed by a sharp increase from late summer into fall. This pattern likely reflects typical seasonal weather variations, with higher pressure systems dominating in winter and lower pressure systems more common in summer.

# %% [markdown]
# #### Year Length
#
# ###### Analysis:
#
# This graph shows the minimum temperature for approximately 2000 terrestrial days. The temperature fluctuates considerably, ranging from about -90°C at its lowest to around -60°C at its highest. There appears to be a pattern, with several distinct warming and cooling periods. The overall trend shows large temperature swings, with the coldest periods reaching below -85°C and the warmest periods peaking above -65°C. The temperature changes are quite dramatic, often shifting relatively short periods. This pattern could indicate seasonal variations on a planet with an eccentric orbit or other periodic climate-influencing factors.

# %% [markdown]
# ### Step 6: Save the Data
#
# Export the DataFrame to a CSV file.

# %%
df.to_csv("output/mars_weather_data.csv", index=False)

# %%
browser.quit()
